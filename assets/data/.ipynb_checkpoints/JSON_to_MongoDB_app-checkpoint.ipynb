# %%
# Load Module

import json
import pandas as pd
from pymongo import MongoClient

# %%
# Make Connection

myclient = MongoClient("mongodb://localhost:27017/")

# %%
# Create database

db_name = myclient["Census_Data"]

# %%
# Swith to Collection

db_collection = db_name["Data"]

# %%
# Load JSON Pandas

internet_census_combined_jdf = pd.read_json('internet_census_combined.json')
internet_census_combined_jdf
# Out:
#                    City  Population  MedianIncome  \
# 0        Aaronsburg, PA        1327       59531.0
# 1         Abbeville, AL        6275       39983.0
# 2         Abbeville, GA        4547       32105.0
# 3         Abbeville, LA       25623       49663.0
# 4         Abbeville, MS        2073       43886.0
# ...                 ...         ...           ...
# 19958  Zumbro Falls, MN        1464       81364.0
# 19959      Zumbrota, MN        4932       70450.0
# 19960        Zurich, MT          73       60938.0
# 19961       Zwingle, IA         729       49917.0
# 19962        Zwolle, LA        5304       35271.0
#
#        PopulationWithHighSchoolDiploma  PopulationWithAssociates  \
# 0                                  274                        56
# 1                                 1329                       433
# 2                                  994                       180
# 3                                 5450                      1216
# 4                                  372                       199
# ...                                ...                       ...
# 19958                              349                       139
# 19959                              974                       492
# 19960                               23                         6
# 19961                              230                        66
# 19962                             1279                       258
#
#        PopulationWithBachelors  PopulationWithHighSpeedInternet   Latitude  \
# 0                           72                              181  40.010823
# 1                          335                             2522  31.564724
# 2                          206                             2465  31.992576
# 3                         1734                            11765  29.975395
# 4                          200                              468  34.503392
# ...                        ...                              ...        ...
# 19958                      133                              181  44.287819
# 19959                      635                             3141  44.295356
# 19960                        5                               19  48.586011
# 19961                       65                               76  42.297197
# 19962                      237                              214  31.639433
#
#         Longitude
# 0      -80.000926
# 1      -85.259123
# 2      -83.306453
# 3      -92.127157
# 4      -89.502517
# ...           ...
# 19958  -92.427083
# 19959  -92.674842
# 19960 -109.030243
# 19961  -90.687446
# 19962  -93.641137
#
# [19963 rows x 9 columns]

# %%
# Document Headers

for index, row in internet_census_combined_jdf.iterrows():
    census_data = { "City" : row['City'],
        "Population" : row['Population'],
        "MedianIncome" : row['MedianIncome'],
        "PopulationWithHighSchoolDiploma" : row['PopulationWithHighSchoolDiploma'],
        "PopulationWithAssociates" : row['PopulationWithAssociates'],
        "PopulationWithBachelors" : row['PopulationWithBachelors'],
        "PopulationWithHighSpeedInternet" : row['PopulationWithHighSpeedInternet'],
        "Latitude" : row['Latitude'],
        "Longitude" : row['Longitude']
        }

# %%
# Insert Pandas Collection 

db_collection.insert_one(census_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-778e0e0b8bbc> in <module>
#       1 # Insert Pandas Collection
#       2
# ----> 3 db_collection.insert_many(census_data)
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     758         write_concern = self._write_concern_for(session)
#     759         blk = _Bulk(self, ordered, bypass_document_validation)
# --> 760         blk.ops = [doc for doc in gen()]
#     761         blk.execute(write_concern, session=session)
#     762         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in <listcomp>(.0)
#     758         write_concern = self._write_concern_for(session)
#     759         blk = _Bulk(self, ordered, bypass_document_validation)
# --> 760         blk.ops = [doc for doc in gen()]
#     761         blk.execute(write_concern, session=session)
#     762         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# ~\Anaconda3\lib\site-packages\pymongo\collection.py in gen()
#     749             """A generator that validates documents and handles _ids."""
#     750             for document in documents:
# --> 751                 common.validate_is_document_type("document", document)
#     752                 if not isinstance(document, RawBSONDocument):
#     753                     if "_id" not in document:
#
# ~\Anaconda3\lib\site-packages\pymongo\common.py in validate_is_document_type(option, value)
#     500     """Validate the type of method arguments that expect a MongoDB document."""
#     501     if not isinstance(value, (abc.MutableMapping, RawBSONDocument)):
# --> 502         raise TypeError("%s must be an instance of dict, bson.son.SON, "
#     503                         "bson.raw_bson.RawBSONDocument, or "
#     504                         "a type that inherits from "
#
# TypeError: document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping

# %%
# Load JSON

# with open ('internet_census_combined.json') as file:
#     file_data = json.load(file)

# %%
# Insert JSON Collection 

# if isinstance(file_data, list):
#     Collection.insert_many(file_data)  
# else:
#     Collection.insert_one(file_data)
