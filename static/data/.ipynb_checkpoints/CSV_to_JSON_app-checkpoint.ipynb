# %%
# Load Modules

import json
import pymongo
import pandas as pd
myclient = pymongo.MongoClient()

# %%
# # Read 'internet2020.csv'

# # Load CSV file
# internet2020_df = pd.read_csv('internet2020.csv' ,encoding = 'ISO-8859-1')
# # Save to JSON file
# internet2020_df.to_json('internet2020.json')
# # Load the JSON file
# internet2020_jdf = open('internet2020.json').read()
# # Read JSON file
# data = json.loads(internet2020_jdf)

# %%
# Read 'Area_Table_June_2020_V1.csv'

# # Load CSV file
# Area_Table_June_2020_V1_df = pd.read_csv('Area_Table_June_2020_V1.csv' ,encoding = 'ISO-8859-1')
# # Save to JSON file
# Area_Table_June_2020_V1_df.to_json('Area_Table_June_2020_V1.json')
# # Load the JSON file
# Area_Table_June_2020_V1_jdf = open('Area_Table_June_2020_V1.json').read()
# # Read JSON file
# data1 = json.loads(Area_Table_June_2020_V1_jdf)

# %%
# # Read 'Geography_Lookup_Table.csv'

# # Load CSV file
# Geography_Lookup_Table_df = pd.read_csv('Geography_Lookup_Table.csv' ,encoding = 'ISO-8859-1')
# # Save to JSON file
# Geography_Lookup_Table_df.to_json('Geography_Lookup_Table.json')
# # Load the JSON file
# Geography_Lookup_Table_jdf = open('Geography_Lookup_Table.json').read()
# # Read JSON file
# data2 = json.loads(Geography_Lookup_Table_jdf)

# %%
# Convert CSV to JSON: 'internet_census_combined.csv'

# Load CSV file
internet_census_combined_df = pd.read_csv('internet_census_combined.csv' ,encoding = 'ISO-8859-1')
# Save to JSON file
internet_census_combined_df.to_json('internet_census_combined.json')
# # Load the JSON file
# internet_census_combined_jdf = open('internet_census_combined.json').read()
# # Read JSON file
# data2 = json.loads(internet_census_combined_jdf)

# %%
# Read JSON into Pandas

internet_census_combined_jdf = pd.read_json('internet_census_combined.json')
internet_census_combined_jdf
# Out:
#                    City  Population  MedianIncome  \
# 0        Aaronsburg, PA        1327       59531.0
# 1         Abbeville, AL        6275       39983.0
# 2         Abbeville, GA        4547       32105.0
# 3         Abbeville, LA       25623       49663.0
# 4         Abbeville, MS        2073       43886.0
# ...                 ...         ...           ...
# 19378  Zumbro Falls, MN        1464       81364.0
# 19379      Zumbrota, MN        4932       70450.0
# 19380        Zurich, MT          73       60938.0
# 19381       Zwingle, IA         729       49917.0
# 19382        Zwolle, LA        5304       35271.0
#
#        PopulationWithHighSchoolDiploma  PopulationWithAssociatesDegree  \
# 0                                  274                              56
# 1                                 1329                             433
# 2                                  994                             180
# 3                                 5450                            1216
# ...
